# %%
#collate all LATEX formulas into a txt file + comparing it to see if theres any left out

# %% [markdown]
# # Collating all LATEX formulas
#
# Need to collate all the latex formulas into a txt file, line by line, and rename(?) that txt file to a .lst file? (apparently lst is just a linux version of txt?)

# %%
#utility function from https://stackoverflow.com/a/48030307

from ctypes import wintypes, windll
from functools import cmp_to_key

def winsort(data):
    _StrCmpLogicalW = windll.Shlwapi.StrCmpLogicalW
    _StrCmpLogicalW.argtypes = [wintypes.LPWSTR, wintypes.LPWSTR]
    _StrCmpLogicalW.restype  = wintypes.INT

    cmp_fnc = lambda psz1, psz2: _StrCmpLogicalW(psz1, psz2)
    return sorted(data, key=cmp_to_key(cmp_fnc))

# %% [markdown]
# ## Generate COLLATED.txt
#
# A txt file with all the groundtruths one after another

# %%
# Import Module

#something wrong with this
#not exhaustive, and also errorunous

import os
i=0
  
# Folder Path
path = "C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed"
#C:\Users\ngzhe\Desktop\CY2001-Research\offline-crohme-master\2019_data_processed
  
# # Change the directory
os.chdir(path)
  
# Read text File  
def read_text_file(file_path):
     with open(file_path, 'r') as f:
         for line in f:
            line = line.strip() #remove leading whitespace
            with open('C://Users//ngzhe//Desktop//CY2001-Research//2019notsorted.txt', 'a', encoding='utf-8') as w:
                
                w.write(line)
                #w.write('\t')
                #w.write(file_path)
                w.write('\n')
                print(line)

# iterate through all file
for file in os.listdir(): #for file in winsort(os.listdir())
    
    # Check whether file is in text format or not
    if file.endswith(".txt"):
        file_path = f"{path}/{file}"
        #assert os.path.isfile(path)
        print(file_path)
        #i+=1
  
        # call read text file function
        read_text_file(file_path)
        
#print(i)
# Out:
# C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed/001-equation000.txt
# $y = Ax + A^2$
# C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed/001-equation001.txt
# $B_n(1-x)=(-1)^n B_n(x)$
# C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed/001-equation0010.txt
# $0 < x < 1$
# C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed/001-equation0011.txt
# $A ( B + C ) = A B + A C$
# C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed/001-equation0012.txt
# $A\times B$
# C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed/001-equation0013.txt
# $A_2>B_2$
# C://Users//ngzhe//Desktop//CY2001-Research//offline-crohme-master//2019_data_processed/001-equation002.txt
# $\forall x \in A, \forall y \in B, x<y$
# ...

# %% [markdown]
# ## Weeding out duplicates, error in groundtruth, see what didnt map over

# %%
#it says 10851, which means the correct num of files were processed
#So the error lies in file processed → but no output?

# %%
# #so now compare the actual directory with the second thing in the txt file
# # Folder Path
# path = "C://Users//ngzhe//Desktop//CY2001-Research//TXT"
  
# # # Change the directory
# os.chdir(path)

# for file in winsort(os.listdir()):
#     path = "C://Users//ngzhe//Desktop//CY2001-Research//TXT"
#     # Check whether file is in text format or not
#     #if file.endswith(".txt"):
#     file_path = f"{path}/{file}"
#     print(file_path, type(file_path))
    
#     i=0
    
#     #check the file path against 
#     with open('C://Users//ngzhe//Desktop//CY2001-Research//COLLATED.txt', 'r') as f:
#          for line in f:
#             line = line.strip()
#             #split into groundtruth and path seperated by tab
#             #line = line.strip() #remove leading whitespace
#             split_string = line.split("\t")
#             if(len(split_string)>2):
#                 print(split_string)
#             groundtruth, path = split_string
#             path = path.strip()
#             #print(path, type(path)) 
#             if(path==file_path):
#                 #print("this file has a match")
#                 i=1
#                 break
                
#             else:
#                 continue
                
#          if(i==0): #outside of for loop, means already traversed text file entirely alr
#             print(file_path + "cant be found in COLLATED")
# Out:
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation000.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation001.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation002.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation003.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation004.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation005.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation006.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation007.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation008.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation009.txt <class 'str'>
# C://Users//ngzhe//Desktop//CY2001-Research//TXT/001-equation0010.txt <class 'str'>
# ...
