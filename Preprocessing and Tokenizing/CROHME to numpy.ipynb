# %% [markdown]
# # CROHME to numpy
#
# fingers crossed, hopefully can get a numpy array w dimensions = num of data * length * height?
#
# and encode the groundtruth similiarly

# %%
import numpy as np
from os import listdir
from PIL import Image
import math
import os

# %%
path = "C://Users//ngzhe//Desktop//CY2001-Research//2019_INKML" 
#C:\Users\ngzhe\Desktop\CY2001-Research\offline-crohme-master\data_processe

# %%
directory = os.fsencode(path)
    
for file in os.listdir(directory):
     filename = os.fsdecode(file)
     if filename.endswith(".png"): 
        img= Image.open(file)
        np_img = numpy.array(img)

        print(np_img.shape)
        numpy.array([np_img,)
        
        continue
        
     elif filename.endswith(".txt"):
        
         continue
# Out:
# 001-equation000.inkml.png
# 001-equation001.inkml.png
# 001-equation0010.inkml.png
# 001-equation0011.inkml.png
# 001-equation0012.inkml.png
# 001-equation0013.inkml.png
# 001-equation002.inkml.png
# 001-equation003.inkml.png
# 001-equation004.inkml.png
# 001-equation005.inkml.png
# 001-equation006.inkml.png
# 001-equation007.inkml.png
# 001-equation008.inkml.png
# 001-equation009.inkml.png
# 002-equation000.inkml.png
# 002-equation001.inkml.png
# 002-equation002.inkml.png
# 002-equation003.inkml.png
# 002-equation004.inkml.png
# 002-equation005.inkml.png
# 002-equation006.inkml.png
# 002-equation007.inkml.png
# 002-equation008.inkml.png
# 002-equation009.inkml.png
# 002-equation010.inkml.png
# 002-equation011.inkml.png
# 002-equation012.inkml.png
# 002-equation013.inkml.png
# 101_alfonso.inkml.png
# 101_carlos.inkml.png
# 101_caue.inkml.png
# 101_danilo.inkml.png
# 101_david.inkml.png
# 101_edwin.inkml.png
# 101_Fabricio.inkml.png
# 101_Frank.inkml.png
# 101_fujita.inkml.png
# ...

# %%
#build a numpy array stacking all these, and a corresponding labels array?

#labels array have strings in them
